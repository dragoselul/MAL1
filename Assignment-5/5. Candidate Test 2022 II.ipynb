# %% [markdown]
# # Candidate Test 2022 Analysis Part 2
#
# This exercise focuses on the candidate tests from two television networks: DR and TV2. Data from both tests have been given on a scale of five responses (-2, -1, 0, 1, 2). Consider normalizing the data or performing similar scaling transformations as needed.
#
# ---
#
# There are 6 datasets included in this exercise:
#
# - `alldata.xlsx`: Contains responses from both TV stations.
# - `drdata.xlsx`: Contains responses from DR.
# - `drq.xlsx`: Contains questions from DR.
# - `tv2data.xlsx`: Contains responses from TV2.
# - `tv2q.xlsx`: Contains questions from TV2.
# - `electeddata.xlsx`: Contains responses from both TV stations for candidates who were elected to the parliament. Note that 9 members are missing; 7 of them didn't take any of the tests. Additionally, some notable figures like Mette F. and Lars Løkke did not participate in any of the tests.
#
# ---
#
# It's entirely up to you how you approach this data, but at a *minimum*, your analysis should include:
#
# - An analysis/description of which questions are most crucial concerning their placement on the axes.
# - Average positions of parties concerning each question, preferably with accompanying plots of each (or selected) question.
# - A clustering analysis where you attempt various cluster numbers, which would correspond to different parties. Discuss whether there is room for more clusters/parties or if a reduction is needed. Make sure you cover: **K-Means, Hierarchical clustering, and DBSCAN.**
# - An overview of the political landscape of the elected candidates, highlighting which members agree or disagree the most and which parties or party members have significant disagreements.
# - Feel free to explore further and remember that preprocessing, methodology, and evaluation metrics are not mentioned explicitly, but are implicitly assumed.
#
# ---
#
# The following parties are represented:
#
# | Party letter | Party name | Party name (English) | Political position |
# | :-: | :-: | :-: | :-: |
# | A | Socialdemokratiet | Social Democrats | Centre-left |
# | V | Venstre | Danish Liberal Party | Centre-right |
# | M | Moderaterne | Moderates | Centre-right |
# | F | Socialistisk Folkeparti | Socialist People's Party | Left-wing |
# | D | Danmarksdemokraterne | Denmark Democrats | Right-wing |
# | I | Liberal Alliance | Liberal Alliance | Right-wing |
# | C | Konservative | Conservative People's Party | Right-wing |
# | Æ | Enhedslisten | Red-Green Alliance | Far-left |
# | B | Radikale Venstre | Social Liberal Party | Centre-left |
# | D | Nye Borgerlige | New Right | Far-right |
# | Z | Alternativet | The Alternative | Centre-left |
# | O | Dansk Folkeparti | Danish People's Party | Far-right |
# | G | Frie Grønne | Free Greens | Centre-left |
# | K | Kristendemokraterne | Christian Democrats | Centre-right |
#
# Below you can see the results and the colors chosen to represent the parties. Use these colors in your analysis above.
#
# ![Alt text](image-1.png)
#
#
# Others have undertaken similar analyses. You can draw inspiration from the following (use Google tranlsate if your Danish is rusty):
#
# - [Analysis of where individual candidates stand relative to each other and their parties](https://v2022.dumdata.dk/)
# - [Candidate Test 2022 – A deep dive into the data](https://kwedel.github.io/kandidattest2022/)
# - [The Political Landscape 2019](https://kwedel.github.io/kandidattest2019/)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from googletrans import Translator
from sklearn.cluster import KMeans, DBSCAN
from sklearn.decomposition import PCA
import seaborn as sns
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.manifold import TSNE
from scipy.cluster.hierarchy import dendrogram, ward

alldata = pd.read_excel('alldata.xlsx')
drdata = pd.read_excel('drdata.xlsx')
drq = pd.read_excel('drq.xlsx')
tv2data = pd.read_excel('tv2data.xlsx')
tv2q = pd.read_excel('tv2q.xlsx')
electeddata = pd.read_excel('electeddata.xlsx')

# %%
# What's where?
print(drq.columns)
print(tv2q.columns)
print(drdata.columns)
print(tv2data.columns)

# Anything missing?
print("dr_data missing elements:", drdata.eq(0).all(axis=1).sum())
print("tv2_data missing elements:", tv2data.eq(0).all(axis=1).sum())
# Out:
# Index(['ID', 'Title', 'Question', 'Info', 'ArgumentFor', 'ArgumentAgainst',
#        'WordMerger', 'ID_CandidateQuestionType', 'Rule', 'QuestionListData'],
#       dtype='object')
# Index(['id', 'type', 'header', 'question', 'depends'], dtype='object')
# Index(['530', '531', '533', '534', '535', '537', '538', '540', '541', '543',
#        '544', '545', '546', '547', '548', '550', '551', '552', '553', '555',
#        '556', '557', '559', '561', '563', 'navn', 'parti'],
#       dtype='object')
# Index(['1a', '1b', '2a', '2b', '3a', '3b', '4a', '4b', '5a', '5b', '6a', '6b',
#        '7a', '7b', '8a', '8b', '9a', '9b', '10a', '10b', '11a', '11b', '12a',
#        '12b', 'parti', 'navn', 'storkreds', 'alder'],
#       dtype='object')
# dr_data missing elements: 0
# tv2_data missing elements: 0

# %%
# Assume `drq` and `tv2q` are defined
dr_questions = drq.rename(columns={'ID': 'id', 'Question': 'question'}).set_index('id')['question']
tv2_questions = tv2q.set_index('id')['question']

# Concatenate questions into one Series
questions = pd.concat([dr_questions, tv2_questions])


#ChatGPTe?
translated_questions = pd.Series({
    '530': 'Denmark should spend more money on strengthening train and bus services rather than building new motorways',
    '531': 'A special tax should be introduced on the very highest incomes',
    '533': 'Crime committed in vulnerable housing areas should be punished particularly severely',
    '534': 'In the long term, Denmark should leave the EU',
    '535': 'It is sensible that Denmark will spend significantly more money on defense in the coming years',
    '537': 'It is okay for economic inequality to increase as long as Danes generally become richer',
    '538': 'Parents\' income should be one of the criteria for distributing students in high schools',
    '540': 'It should be possible to make a profit from running private kindergartens and nurseries',
    '541': 'Tax should be introduced on profits from home sales',
    '543': 'It is a good idea that the unemployment benefit rate for new graduates has been reduced',
    '544': 'Transgender people under 18 should have the option for legal gender change (changing CPR number)',
    '545': 'The retirement age should continue to rise in line with increasing life expectancy',
    '546': 'Denmark should investigate the possibility of developing nuclear power as an energy source domestically',
    '547': 'A government should be formed across the center',
    '548': 'Money should be allocated to help social benefit recipients when prices rise',
    '550': 'Quotas should be introduced ensuring at least 30 percent women on company boards',
    '551': 'There should be permanent border control between Denmark and Germany',
    '552': 'One should automatically become an organ donor at 18 unless actively opting out',
    '553': 'More education places should be relocated from the big cities',
    '555': 'Asylum seekers should be sent to a country outside the EU - e.g., Rwanda - while their application is processed',
    '556': 'The so-called Arne pension should be abolished',
    '557': 'Wages for employees in classic welfare professions like nurses and educators should be significantly increased',
    '559': 'Denmark should introduce CO2 tax on air travel',
    '561': 'It is a good idea to have nature national parks where large animals are released to live wild',
    '563': 'Young people up to 24 years should have the right to free public psychological help without doctor referral',
    'bornholm-1': 'The state should ensure sufficient doctors, nurses, dentists, chiropractors and other healthcare professionals on Bornholm through particularly attractive conditions',
    'bornholm-2': 'The state should ensure that air traffic to and from Bornholm gets status as socially conditioned route and possibility for operational subsidies on par with ferry traffic',
    'bornholm-3': 'More money should be allocated to Defense presence on water, land and in the air on Bornholm',
    'bornholm-4': 'It should be easier to bring in foreign labor to Bornholm',
    'bornholm-5': 'The decision to establish a nature national park on a piece of Almindingen with fenced areas with large animals should be reversed',
    'fyns-1': 'Police should be given more money to combat gang crime in vulnerable housing areas',
    'fyns-2': 'It should be free to cross the Great Belt Bridge at the expense of funding other state infrastructure projects',
    'fyns-3': 'Langeland Municipality should merge with Svendborg Municipality to address economic problems',
    'fyns-4': 'The state should ensure cheaper ferries between Danish islands year-round at the expense of expanding other traffic projects like motorways and railways',
    'fyns-5': 'Even more higher education places should be moved from Odense to other Funen cities',
    'københavns omegns-1': 'It is more important to invest in sustainable transport like public transit and cycling than expanding motorways such as Hillerød motorway, Frederikssund motorway and Motor Ring 3 and 4',
    'københavns omegns-2': 'Less money should be sent from East to West Denmark in municipal equalization',
    'københavns omegns-3': 'There should be stricter environmental requirements for industry and agriculture near nature areas like streams and lakes to prevent pollution discharge, even if requirements mean extra costs for businesses',
    'københavns omegns-4': 'To reduce congestion, air pollution and CO₂ emissions, road pricing should be introduced so motorists are taxed for driving in Copenhagen and surrounding municipalities Hvidovre, Rødovre, Herlev, Gladsaxe and Gentofte',
    'københavns omegns-5': 'To get more people in the capital to choose bikes over cars, a special travel deduction should be introduced for cyclists so commuters cycling six kilometers or more to work can get a tax deduction',
    'københavns-1': 'Overall it was the right decision to move state workplaces and education outside the capital',
    'københavns-2': 'To reduce congestion, air pollution and CO₂ emissions, road pricing should be introduced so motorists are taxed for driving in Copenhagen',
    'københavns-3': 'Copenhagen should become a trial city for cannabis legalization where state-owned and operated shops can sell cannabis to citizens over 18',
    'københavns-4': 'The artificial peninsula Lynetteholm is a good project',
    'københavns-5': 'The possibility to demolish public housing, sell public housing to private owners or forcibly relocate residents, as for example in Mjølnerparken and Tingbjerg, should be abolished, partly because there is a shortage of affordable housing in Copenhagen',
    'nordjyllands-1': 'It should be easier to get housing loans in sparsely populated areas through state guarantee for part of the home loan',
    'nordjyllands-2': 'Parliament should expand the number of fenced nature national parks in North Jutland where wild horses, cattle and bison are released',
    'nordjyllands-3': 'A third Limfjord connection should be built over Egholm island - even if it potentially affects environment and wildlife on Egholm',
    'nordjyllands-4': 'Study places should be moved from Denmark\'s four largest cities so higher education is spread across the country',
    'nordjyllands-5': 'North Jutland should host new giant wind turbines up to 450 meters as part of a new national test center',
    'nordsjællands-1': 'Less money should be sent from East to West Denmark in municipal equalization',
    'nordsjællands-2': 'It is more important to invest in sustainable transport like public transit and cycling than expanding motorways like Hillerød motorway and Frederikssund motorway',
    'nordsjællands-3': 'It is good that Gribskov along with Hellebæk Forest and Teglstrup Hegn will be converted to nature national parks, even though it means the areas will be fenced',
    'nordsjællands-4': 'There should be stricter environmental requirements for industry and agriculture near nature areas like streams and lakes to prevent pollution discharge, even if requirements mean extra costs for businesses',
    'nordsjællands-5': 'More should be done to reduce traffic noise for residents along state roads in North Zealand. The state should finance this more than previously, even if at the expense of other infrastructure projects',
    'sjællands-1': 'Over 45,000 citizens in Zealand region don\'t have their own permanent family doctor. The state should earmark money for general practitioners instead of spending on building new local hospitals and large central hospitals',
    'sjællands-2': 'It should be made easier to set up wind turbines and solar cells on land - as we saw at Kriegers Flak off Møn where lengthy case processing and complaints from neighbors and nature organizations unnecessarily delay projects',
    'sjællands-3': 'At an old fire school in Korsør, pollution with toxic PFOS/PFAS substances has affected a large local group, and up to 15,000 plots in Denmark are estimated contaminated with these substances. The government/Parliament should allocate more money to clean the contaminated sites',
    'sjællands-4': 'A fixed connection across Kattegat should be abandoned. It\'s too expensive and the wrong choice climate-wise',
    'sjællands-5': 'It\'s a good idea that the government has decided to spend about a billion kroner on a gas pipeline from Everdrup in South Zealand to Lolland and Falster. This means among other things that Nordic Sugar\'s factories in Nakskov and Nykøbing F., which are major energy consumers, can switch from oil and coal to natural gas - and later biogas',
    'sydjyllands-1': 'It is acceptable to forcibly relocate residents in housing areas like Stengårdsvej in Esbjerg, Nørager/Søstjernevej and others in Sønderborg, Sundparken in Horsens and Skovvejen/Skovparken in Kolding to combat parallel societies and crime',
    'sydjyllands-2': 'The temporary border control at the Danish-German border should stop when the current period expires in November',
    'sydjyllands-3': 'Students should get higher student grants (SU) for choosing higher education in cities like Esbjerg, Vejle, Sønderborg, Haderslev and Kolding rather than in the country\'s four largest cities',
    'sydjyllands-4': 'A bridge should be built from Als to Funen',
    'sydjyllands-5': 'The state should ensure more attractive working conditions and higher wages for doctors who settle in outlying areas in South and Southern Jutland, so doctor shortages in certain areas of the region can be addressed',
    'vestjyllands-1': 'Although there were many jobs in mink farming in Central and West Jutland, it is better that mink farming is banned once and for all',
    'vestjyllands-2': 'The state should ensure healthcare personnel in municipalities where it is difficult to attract doctors and other healthcare staff',
    'vestjyllands-3': 'Citizens in municipalities where it is windiest must accept that this is also where most wind turbines are installed',
    'vestjyllands-4': 'Car taxes should be changed to make driving cheaper in rural areas with poor access to public transport',
    'vestjyllands-5': 'It is better to invest more in green transition than investing in roads such as the Army Road motorway, the main road between Skive and Herning and a 2+1 road between Herning and Ringkøbing',
    'østjyllands-1': 'More untouched nature national parks should be established in East Jutland with wild large animals like horses and cattle',
    'østjyllands-2': 'A Kattegat bridge should be built over Samsø',
    'østjyllands-3': 'It should be easier for municipalities to give permission for solar cells and wind turbines, even though it is often met with criticism from local populations',
    'østjyllands-4': 'More higher education programs in Aarhus should be moved to other smaller provincial towns for example Randers or Horsens',
    'østjyllands-5': 'Motorway E45 should be expanded to six lanes on the stretch between Aarhus North and Randers',
    '1a': 'Beef should be subject to a climate tax, making half a kilo of minced beef ten kroner more expensive',
    '1b': 'The companies that emit the most CO₂ should pay more in taxes - even if it might cost Danish jobs',
    '2a': 'Parliament should allocate funds targeted at improving wages and working conditions among selected staff groups in the healthcare sector',
    '2b': 'Cigarettes should be subject to an extra tax of 20 kroner per pack',
    '3a': 'Denmark should spend two percent of GDP on defense before 2033 begins',
    '3b': 'Development aid should be increased',
    '4a': 'Economic inequality in Danish society should be reduced',
    '4b': 'The state should do more to compensate Danes for the rising prices that inflation has caused',
    '5a': 'It is necessary to introduce user payment in elderly care to ensure there is enough money for the increasing number of elderly',
    '5b': 'Additional resources should be allocated to elderly care, even if this means other welfare areas get fewer resources',
    '6a': 'Danish immigration policy is too strict',
    '6b': 'It would be a good idea to establish a Danish asylum reception center in Rwanda',
    '7a': 'Introduction of nuclear power in Denmark would be a good contribution to the green transition',
    '7b': 'Denmark should become totally independent of Russian gas and oil as soon as possible, even if it means increased use of coal which is more harmful to the climate',
    '8a': 'Significantly more resources should be allocated to mentally vulnerable young people, even if this means other welfare areas get fewer resources',
    '8b': 'Additional resources should be allocated to caring for the youngest children, even if this means other welfare areas get fewer resources',
    '9a': 'Parts of the student grant (SU) for higher education should be converted to loans to secure resources for other parts of the education sector',
    '9b': 'Schools should do more to help particularly challenged children, even if it will be at the expense of help for other students',
    '10a': 'The public sector currently spends too much money helping people who could manage on their own, and too little money on people who really need help',
    '10b': 'The so-called Arne pension, which allows earlier retirement, should be maintained even though there is a shortage of labor',
    '11a': 'There has been too much focus on Mette Frederiksen\'s handling of the Mink case - under the circumstances she did the right thing',
    '11b': 'It should be investigated whether Mette Frederiksen can be brought before the State Court as a consequence of her handling of the Mink case',
    '12a': 'If corona infection rises significantly in winter, society should be kept as open as possible, even if it could cost lives',
    '12b': 'If corona infection rises significantly in winter, regular tests should be required for unvaccinated people in Denmark'
})

translated_questions
# Out:
# 530    Denmark should spend more money on strengtheni...
# 531    A special tax should be introduced on the very...
# 533    Crime committed in vulnerable housing areas sh...
# 534        In the long term, Denmark should leave the EU
# 535    It is sensible that Denmark will spend signifi...
#                              ...
# 10b    The so-called Arne pension, which allows earli...
# 11a    There has been too much focus on Mette Frederi...
# 11b    It should be investigated whether Mette Freder...
# 12a    If corona infection rises significantly in win...
# 12b    If corona infection rises significantly in win...
# Length: 99, dtype: object

# %%
# Separate questions and combine them with answers
answers = alldata[alldata.columns[alldata.columns.astype(str).isin(questions.index.astype(str))]]

other_data = alldata.drop(answers.columns, axis=1)

print(answers.columns)
print(other_data.columns)

qa = answers.copy()
qa.columns = translated_questions[translated_questions.index.astype(str).isin(qa.columns.astype(str))]

qa_sorted = qa.T
qa_sorted
# Out:
# Index(['530', '531', '533', '534', '535', '537', '538', '540', '541', '543',
#        '544', '545', '546', '547', '548', '550', '551', '552', '553', '555',
#        '556', '557', '559', '561', '563', '1a', '1b', '2a', '2b', '3a', '3b',
#        '4a', '4b', '5a', '5b', '6a', '6b', '7a', '7b', '8a', '8b', '9a', '9b',
#        '10a', '10b', '11a', '11b', '12a', '12b'],
#       dtype='object')
# Index(['navn', 'parti', 'storkreds', 'alder'], dtype='object')
#                                                     0    1    2    3    4    \
# Denmark should spend more money on strengthenin...   -1    2    2    2    1
# A special tax should be introduced on the very ...   -2    2    1    1    1
# Crime committed in vulnerable housing areas sho...    1   -1   -2   -2   -2
# In the long term, Denmark should leave the EU        -2   -2   -2   -1    2
# It is sensible that Denmark will spend signific...    2   -1    1    1   -2
# It is okay for economic inequality to increase ...    1   -2   -2    1    1
# Parents' income should be one of the criteria f...   -2    1    1    1   -2
# It should be possible to make a profit from run...    1   -2   -1    1    1
# Tax should be introduced on profits from home s...    1    2    1    1    2
# It is a good idea that the unemployment benefit...    2   -2   -1   -2   -2
# Transgender people under 18 should have the opt...   -2    2    2    2   -2
# The retirement age should continue to rise in l...    1   -1   -2    1    2
# Denmark should investigate the possibility of d...    2   -2   -2    1    2
# A government should be formed across the center       2   -2   -1   -2   -2
# Money should be allocated to help social benefi...    1    2    1    2    2
# Quotas should be introduced ensuring at least 3...   -2    2    1    2    1
# There should be permanent border control betwee...    1   -2   -2   -2   -2
# One should automatically become an organ donor ...    2    1    2    2    2
# More education places should be relocated from ...   -2    1   -1    1   -2
# Asylum seekers should be sent to a country outs...    2   -1   -2    2   -2
# The so-called Arne pension should be abolished        2   -2   -1   -2   -1
# Wages for employees in classic welfare professi...    1    1    1    2    1
# Denmark should introduce CO2 tax on air travel        2    2    2    2   -2
# It is a good idea to have nature national parks...    2    1    2    2   -1
# Young people up to 24 years should have the rig...   -2    2    2    2   -2
# Beef should be subject to a climate tax, making...    0    1    1    2   -2
# The companies that emit the most CO₂ should pay...    0    1    1    2   -2
# Parliament should allocate funds targeted at im...    2    1    1    2    0
# Cigarettes should be subject to an extra tax of...    2    1    2    2    0
# Denmark should spend two percent of GDP on defe...    2    1    1    0   -2
# Development aid should be increased                  -2    2    1    2   -2
# Economic inequality in Danish society should be...   -1    2    2    0    2
# The state should do more to compensate Danes fo...    0    2    0    2    1
# It is necessary to introduce user payment in el...   -1   -2   -1   -2   -2
# Additional resources should be allocated to eld...    1    0    1    2    2
# Danish immigration policy is too strict              -1    1    2   -1    1
# It would be a good idea to establish a Danish a...    1   -2   -2    2   -2
# Introduction of nuclear power in Denmark would ...    2   -2   -2    0    2
# Denmark should become totally independent of Ru...    2    0   -2   -2   -2
# Significantly more resources should be allocate...    1    0    1    2    1
# Additional resources should be allocated to car...    0    0    1    2    0
# Parts of the student grant (SU) for higher educ...    2   -2   -1   -2   -2
# Schools should do more to help particularly cha...    0    0   -2    2    0
# The public sector currently spends too much mon...    1   -1    0    2   -1
# The so-called Arne pension, which allows earlie...   -2    2    2    2    0
# There has been too much focus on Mette Frederik...   -2    1    0    2   -2
# It should be investigated whether Mette Frederi...    1   -2   -1   -1    0
# If corona infection rises significantly in wint...    1    0    1    2    2
# If corona infection rises significantly in wint...    1    0   -2    0   -2
#
#                                                     5    6    7    8    9    \
# Denmark should spend more money on strengthenin...    2    1   -1    1    1
# A special tax should be introduced on the very ...    1    2    2   -1    1
# Crime committed in vulnerable housing areas sho...   -2   -1   -2   -1   -2
# In the long term, Denmark should leave the EU        -2   -2   -2   -1   -2
# It is sensible that Denmark will spend signific...   -1    1   -2    2    1
# It is okay for economic inequality to increase ...   -1    1   -2   -1   -2
# Parents' income should be one of the criteria f...   -1   -2   -1   -1   -2
# It should be possible to make a profit from run...    1    1   -1    1   -1
# Tax should be introduced on profits from home s...    1    1    1    2    1
# It is a good idea that the unemployment benefit...   -1   -1   -1    1   -2
# Transgender people under 18 should have the opt...    1    1    2    1    2
# The retirement age should continue to rise in l...   -1    1   -1   -1   -2
# Denmark should investigate the possibility of d...    1    2    1    2   -1
# A government should be formed across the center       1    2   -2    1    1
# Money should be allocated to help social benefi...    1   -1    1    1    1
# Quotas should be introduced ensuring at least 3...    1    1    2    1    2
# There should be permanent border control betwee...   -2   -1   -2   -2   -2
# One should automatically become an organ donor ...   -1    2    2    1    1
# More education places should be relocated from ...   -1   -2   -1    2   -2
# Asylum seekers should be sent to a country outs...   -2   -1   -2   -2   -2
# The so-called Arne pension should be abolished       -1    2    2   -1   -2
# Wages for employees in classic welfare professi...    1    1    1   -1    2
# Denmark should introduce CO2 tax on air travel        2    1    2    2    2
# It is a good idea to have nature national parks...    2   -1    1    1    1
# Young people up to 24 years should have the rig...    2    2    1   -1    2
# Beef should be subject to a climate tax, making...    2    1    2    2    1
# The companies that emit the most CO₂ should pay...    2    2    2    2    2
# Parliament should allocate funds targeted at im...   -1    2    1   -1    2
# Cigarettes should be subject to an extra tax of...   -1    2    2    2    0
# Denmark should spend two percent of GDP on defe...    0    2    1    1    2
# Development aid should be increased                   2    0    2    0    1
# Economic inequality in Danish society should be...    1    1    2    2    2
# The state should do more to compensate Danes fo...    1   -1    1   -2    2
# It is necessary to introduce user payment in el...   -1    0   -1   -1   -1
# Additional resources should be allocated to eld...    1   -1    2   -1    0
# Danish immigration policy is too strict               2    1    2    1    1
# It would be a good idea to establish a Danish a...   -1   -1   -2   -2   -2
# Introduction of nuclear power in Denmark would ...    0    2   -1    2    0
# Denmark should become totally independent of Ru...   -2   -2    2    1    2
# Significantly more resources should be allocate...    1    2    2    0    0
# Additional resources should be allocated to car...    0   -1    2   -1    0
# Parts of the student grant (SU) for higher educ...   -1    1   -2    1   -2
# Schools should do more to help particularly cha...    0   -1    2    0   -2
# The public sector currently spends too much mon...    1    1   -2    0   -2
# The so-called Arne pension, which allows earlie...    1   -2   -2    0    2
# There has been too much focus on Mette Frederik...   -1   -2   -1    2    0
# It should be investigated whether Mette Frederi...    2    1    0   -2    0
# If corona infection rises significantly in wint...    2    1    1    1    1
# If corona infection rises significantly in wint...   -2    0   -1   -2   -2
#
#                                                     ...  857  858  859  860  \
# Denmark should spend more money on strengthenin...  ...    2    2    1    1
# A special tax should be introduced on the very ...  ...   -2   -1    1    1
# Crime committed in vulnerable housing areas sho...  ...   -2   -1   -1    2
# In the long term, Denmark should leave the EU       ...   -2   -2   -2   -2
# It is sensible that Denmark will spend signific...  ...    2   -1    2    2
# It is okay for economic inequality to increase ...  ...   -1   -1   -1   -1
# Parents' income should be one of the criteria f...  ...    1    1    1    1
# It should be possible to make a profit from run...  ...    1    1   -1   -1
# Tax should be introduced on profits from home s...  ...   -1   -1   -1   -1
# It is a good idea that the unemployment benefit...  ...   -1   -1    1    1
# Transgender people under 18 should have the opt...  ...    2   -1    1   -1
# The retirement age should continue to rise in l...  ...    2    1    1    1
# Denmark should investigate the possibility of d...  ...    1   -1   -2   -1
# A government should be formed across the center     ...    2    2    1    1
# Money should be allocated to help social benefi...  ...    1   -1    1    1
# Quotas should be introduced ensuring at least 3...  ...    1    1    1   -2
# There should be permanent border control betwee...  ...   -2   -2    1    1
# One should automatically become an organ donor ...  ...    2   -1    2   -1
# More education places should be relocated from ...  ...   -2   -2    1    1
# Asylum seekers should be sent to a country outs...  ...   -2   -1    1    2
# The so-called Arne pension should be abolished      ...    1   -1   -2   -2
# Wages for employees in classic welfare professi...  ...   -1    2    1    1
# Denmark should introduce CO2 tax on air travel      ...    2   -1    2    1
# It is a good idea to have nature national parks...  ...    2    1    2    1
# Young people up to 24 years should have the rig...  ...   -1    1    1    1
# Beef should be subject to a climate tax, making...  ...    1    0    0   -1
# The companies that emit the most CO₂ should pay...  ...    2    1    2    0
# Parliament should allocate funds targeted at im...  ...    0    1    2    1
# Cigarettes should be subject to an extra tax of...  ...    2    0    1    0
# Denmark should spend two percent of GDP on defe...  ...    2    1    1    1
# Development aid should be increased                 ...    2    0    1   -1
# Economic inequality in Danish society should be...  ...    1    1    1    1
# The state should do more to compensate Danes fo...  ...   -1    0    2    1
# It is necessary to introduce user payment in el...  ...   -2   -1   -2   -1
# Additional resources should be allocated to eld...  ...    0    0    1    1
# Danish immigration policy is too strict             ...    1    2   -1   -1
# It would be a good idea to establish a Danish a...  ...   -2   -2    1    2
# Introduction of nuclear power in Denmark would ...  ...    0   -1   -2   -1
# Denmark should become totally independent of Ru...  ...   -1    0    2    2
# Significantly more resources should be allocate...  ...    1    1    1    1
# Additional resources should be allocated to car...  ...    1    1    0    0
# Parts of the student grant (SU) for higher educ...  ...   -2   -2   -1    0
# Schools should do more to help particularly cha...  ...   -1   -2    0   -1
# The public sector currently spends too much mon...  ...    0    0   -1    1
# The so-called Arne pension, which allows earlie...  ...   -1    1    2    2
# There has been too much focus on Mette Frederik...  ...   -1   -1    1    1
# It should be investigated whether Mette Frederi...  ...   -2    0   -2   -2
# If corona infection rises significantly in wint...  ...    2    1    1    1
# If corona infection rises significantly in wint...  ...    0   -1    0    0
#
#                                                     861  862  863  864  865  \
# Denmark should spend more money on strengthenin...    1    1    1    1    1
# A special tax should be introduced on the very ...    1    1   -2    1   -1
# Crime committed in vulnerable housing areas sho...    1    1   -2    1    1
# In the long term, Denmark should leave the EU        -2   -2   -2   -2   -2
# It is sensible that Denmark will spend signific...    2    2    1    2    1
# It is okay for economic inequality to increase ...   -1   -1   -2   -1   -1
# Parents' income should be one of the criteria f...    1    1   -1    1   -1
# It should be possible to make a profit from run...   -1   -2   -2   -1   -1
# Tax should be introduced on profits from home s...   -1    1   -2   -1   -1
# It is a good idea that the unemployment benefit...    1    1   -2    1    1
# Transgender people under 18 should have the opt...    1    2    1    1   -1
# The retirement age should continue to rise in l...    1   -1   -2    1    1
# Denmark should investigate the possibility of d...   -2   -1    1   -2   -1
# A government should be formed across the center      -1    1   -1    2   -1
# Money should be allocated to help social benefi...    1    1    2    1    1
# Quotas should be introduced ensuring at least 3...    1    1   -1    1   -1
# There should be permanent border control betwee...    1    1   -1    1    1
# One should automatically become an organ donor ...    1   -1    2    1    1
# More education places should be relocated from ...   -1    1    1    2   -1
# Asylum seekers should be sent to a country outs...    1    1   -1    2    1
# The so-called Arne pension should be abolished       -2   -2   -2   -2   -2
# Wages for employees in classic welfare professi...    1    2    2    1    1
# Denmark should introduce CO2 tax on air travel        1    0    2    1    1
# It is a good idea to have nature national parks...    1    2   -1    1    1
# Young people up to 24 years should have the rig...    1    1    1    1    1
# Beef should be subject to a climate tax, making...    0    0   -1   -1   -1
# The companies that emit the most CO₂ should pay...    1    1    1    1    0
# Parliament should allocate funds targeted at im...    2    1    2    1    1
# Cigarettes should be subject to an extra tax of...    0    1    0    1    0
# Denmark should spend two percent of GDP on defe...    2    2    1    0    0
# Development aid should be increased                   0   -1   -1   -1    0
# Economic inequality in Danish society should be...    1    2    1    1    1
# The state should do more to compensate Danes fo...    1    1    1    1    1
# It is necessary to introduce user payment in el...   -1   -2   -2   -2    0
# Additional resources should be allocated to eld...    0    2    1   -2    0
# Danish immigration policy is too strict              -1    1   -2   -2   -1
# It would be a good idea to establish a Danish a...    2    1   -2    2    1
# Introduction of nuclear power in Denmark would ...   -1   -2   -2   -2   -1
# Denmark should become totally independent of Ru...    1    1    2    2    0
# Significantly more resources should be allocate...    1    2    1    1    0
# Additional resources should be allocated to car...    0    1    0    0    0
# Parts of the student grant (SU) for higher educ...   -1    1   -1   -1    0
# Schools should do more to help particularly cha...    0    2    0    0    0
# The public sector currently spends too much mon...   -1   -1   -1   -1    0
# The so-called Arne pension, which allows earlie...    2    2    2    2    2
# There has been too much focus on Mette Frederik...    1    1    2    2    1
# It should be investigated whether Mette Frederi...   -2   -2   -2   -2   -2
# If corona infection rises significantly in wint...    1    0    0    0    1
# If corona infection rises significantly in wint...    1    0    0    1    0
#
#                                                     866
# Denmark should spend more money on strengthenin...    1
# A special tax should be introduced on the very ...    1
# Crime committed in vulnerable housing areas sho...   -1
# In the long term, Denmark should leave the EU        -2
# It is sensible that Denmark will spend signific...    1
# It is okay for economic inequality to increase ...   -1
# Parents' income should be one of the criteria f...    1
# It should be possible to make a profit from run...   -1
# Tax should be introduced on profits from home s...    1
# It is a good idea that the unemployment benefit...   -1
# Transgender people under 18 should have the opt...    1
# The retirement age should continue to rise in l...    1
# Denmark should investigate the possibility of d...   -1
# A government should be formed across the center       1
# Money should be allocated to help social benefi...    1
# Quotas should be introduced ensuring at least 3...    1
# There should be permanent border control betwee...   -1
# One should automatically become an organ donor ...    1
# More education places should be relocated from ...    1
# Asylum seekers should be sent to a country outs...   -1
# The so-called Arne pension should be abolished       -2
# Wages for employees in classic welfare professi...    1
# Denmark should introduce CO2 tax on air travel        2
# It is a good idea to have nature national parks...    2
# Young people up to 24 years should have the rig...    1
# Beef should be subject to a climate tax, making...    1
# The companies that emit the most CO₂ should pay...    1
# Parliament should allocate funds targeted at im...    1
# Cigarettes should be subject to an extra tax of...    1
# Denmark should spend two percent of GDP on defe...   -1
# Development aid should be increased                   2
# Economic inequality in Danish society should be...    2
# The state should do more to compensate Danes fo...    1
# It is necessary to introduce user payment in el...   -1
# Additional resources should be allocated to eld...    1
# Danish immigration policy is too strict              -1
# It would be a good idea to establish a Danish a...   -1
# Introduction of nuclear power in Denmark would ...   -1
# Denmark should become totally independent of Ru...    2
# Significantly more resources should be allocate...    1
# Additional resources should be allocated to car...    1
# Parts of the student grant (SU) for higher educ...   -2
# Schools should do more to help particularly cha...   -1
# The public sector currently spends too much mon...   -1
# The so-called Arne pension, which allows earlie...    2
# There has been too much focus on Mette Frederik...    2
# It should be investigated whether Mette Frederi...   -2
# If corona infection rises significantly in wint...    1
# If corona infection rises significantly in wint...    0
#
# [49 rows x 867 columns]

# %%
from matplotlib.colors import ListedColormap

# Thank you brother GPT
partiColors = {
    'Socialdemokratiet': '#FF6347',  # Tomato Red
    'Radikale Venstre': '#4682B4',   # Steel Blue
    'Det Konservative Folkeparti': '#32CD32',  # Lime Green
    'Nye Borgerlige': '#8A2BE2',     # Blue Violet
    'Socialistisk Folkeparti': '#FF1493',  # Deep Pink
    'Liberal Alliance': '#00CED1',   # Dark Turquoise
    'Kristendemokraterne': '#A9A9A9', # Dark Gray
    'Moderaterne': '#6A5ACD',        # Slate Blue
    'Dansk Folkeparti': '#FFD700',   # Gold
    'Frie Grønne, Danmarks Nye Venstrefløjsparti': '#228B22',  # Forest Green
    'Venstre': '#1E90FF',            # Dodger Blue
    'Danmarksdemokraterne': '#87CEFA', # Light Sky Blue
    'Enhedslisten': '#FF4500',       # Orange Red
    'Alternativet': '#32CD32',       # Lime Green (same as above, can adjust if desired)
    'Løsgænger': '#000080'           # Navy Blue
}

parties = {party: partiColors[party] for party in other_data['parti'].unique().tolist()}

cmap = ListedColormap(list(parties.values()))
print(parties)

qa[qa_sorted.index].groupby(other_data['parti']).median().T.iloc[:10].plot(kind='barh', figsize=(8, 24), colormap=cmap)
plt.show()
# Out:
# {'Moderaterne': '#6A5ACD', 'Socialistisk Folkeparti': '#FF1493', 'Alternativet': '#32CD32', 'Løsgænger': '#000080', 'Enhedslisten': '#FF4500', 'Danmarksdemokraterne': '#87CEFA', 'Venstre': '#1E90FF', 'Frie Grønne, Danmarks Nye Venstrefløjsparti': '#228B22', 'Dansk Folkeparti': '#FFD700', 'Kristendemokraterne': '#A9A9A9', 'Liberal Alliance': '#00CED1', 'Nye Borgerlige': '#8A2BE2', 'Det Konservative Folkeparti': '#32CD32', 'Radikale Venstre': '#4682B4', 'Socialdemokratiet': '#FF6347'}

# %%
# K-means
costs = []
ks = range(4, 13)
for k in ks:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(qa_sorted)
    costs.append(kmeans.inertia_)
plt.plot(ks, costs, '.-', markersize=22)
plt.xlabel('K clusters')
plt.ylabel('Intertia')
plt.show()
# Using elbow method we can say tha we have at least 4 elbows (k = 4) Though in this specific example it is apparent that elbow method is not enough.

# PCA
party_positions = qa.groupby(other_data['parti']).median()

pca = PCA(n_components=2)
party_pca = pca.fit_transform(party_positions)

plt.figure(figsize=(10, 10))

for i, party in enumerate(party_positions.index):
    plt.scatter(party_pca[i, 0], party_pca[i, 1], color=parties[party], s=100, label=party)
    plt.annotate(party, (party_pca[i, 0], party_pca[i, 1]), 
                 xytext=(5, 5), textcoords='offset points')

plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('PCA of Party Positions')
plt.show()

# For PCA would be logical to have k = 5

# Individual PCA
individual_pca = pca.fit_transform(qa)
individual_pca[:, 1] *= -1
party_positions_after = pd.DataFrame(individual_pca, 
                                     columns=['PC1', 'PC2_inverse']).groupby(other_data['parti']).median()

plt.figure(figsize=(10, 10))

for party in other_data['parti'].unique():
    mask = other_data['parti'] == party
    plt.scatter(individual_pca[mask, 0], individual_pca[mask, 1], 
                color=parties[party], alpha=0.6, label=party)
    
    plt.annotate(party, 
                 (party_positions_after.loc[party, 'PC1'], 
                  party_positions_after.loc[party, 'PC2_inverse']),
                 xytext=(5, 5), textcoords='offset points')

plt.title('Individual Positions by Party')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2 (Inverted)')
plt.legend(loc='best', fontsize=8)
plt.show()

# Significant overlap of some of the parties indicating similarity in answers

# K Clusters
kmeans = KMeans(n_clusters=5, random_state=42)
kmeans_clusters = kmeans.fit_predict(individual_pca)
fig, ax = plt.subplots(figsize=(10, 8))
scatter = ax.scatter(individual_pca[:, 0], individual_pca[:, 1], 
                     c=kmeans_clusters, cmap='rainbow', alpha=0.6)

ax.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], 
           color='black', marker='x', s=200, linewidth=3)

ax.set_title('K Clusters')
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
plt.show()

# Obvious k = 5

# %%
# TSNE

tsne = TSNE(n_components=2, random_state=7, perplexity=10)
one_tsne = tsne.fit_transform(qa)

mask = clusters != -1
silhouette_vals = silhouette_samples(one_tsne[mask], clusters[mask])
silhouette_avg = silhouette_score(one_tsne[mask], clusters[mask])

fig, ax = plt.subplots(figsize=(10, 8))
y_lower = 10
unique_clusters = np.unique(clusters[mask])
color_map = plt.cm.rainbow
norm = plt.Normalize(vmin=min(clusters), vmax=max(clusters))

for cluster in unique_clusters:
    cluster_silhouette_vals = silhouette_vals[clusters[mask] == cluster]
    cluster_silhouette_vals.sort()
    
    size_cluster = len(cluster_silhouette_vals)
    y_upper = y_lower + size_cluster
    
    color = color_map(norm(cluster))
    ax.fill_betweenx(np.arange(y_lower, y_upper),
                     0, cluster_silhouette_vals,
                     facecolor=color, edgecolor=color, alpha=0.7)
    ax.text(-0.05, y_lower + 0.5 * size_cluster, f'Cluster {cluster}')
    y_lower = y_upper + 10

# Average silhouette score line
ax.axvline(x=silhouette_avg, color="red", linestyle="--", label=f'Average Silhouette Score: {silhouette_avg:.3f}')

ax.set_title('Silhouette Plot for DBSCAN Clustering')
ax.set_xlabel('Silhouette Coefficient')
ax.set_ylabel('Cluster')
ax.legend(loc='lower right')
plt.show()

# %% [markdown]
# The data looks mostly looks on the brink of survival: Average score shows a lot of noise and overlapping data, and on some clusters 1-3 we have lots of negative data. Cluster 4 an 0 are mostly okay.

# %%
# Let's do some DBSCAN
fig, ax = plt.subplots(figsize=(10, 8))

scatter = ax.scatter(one_tsne[:, 0], one_tsne[:, 1],
                     c=clusters, cmap='rainbow', alpha=0.9)

# noise points
noise_mask = clusters == -1
ax.scatter(one_tsne[noise_mask, 0], one_tsne[noise_mask, 1], 
           color='gray', alpha=0.7, label='Noise')

ax.set_title('DBSCAN')
ax.set_xlabel('d1')
ax.set_ylabel('d2')
legend = ax.legend(loc='upper right', title='Clusters')
plt.colorbar(scatter, ax=ax, label='Cluster Labels')
plt.show()

# %%
# Hierarchical
linkage_array = ward(qa)  
fig, ax = plt.subplots(figsize = (5,5))
dendrogram(linkage_array, ax = ax)
ax.set_ylabel('Distance')
plt.show()

# %%
corr = qa.T.corr()

# Raw correlation heatmap
fig, ax2 = plt.subplots(1, figsize=(20, 16))
sns.heatmap(corr, ax=ax2, cmap='RdBu_r', center=0, xticklabels=False, yticklabels=False)
ax2.set_title('Raw Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Raw Correlation Matrix')

# %%
# 2. raw correlation with party colors
fig, ax3 = plt.subplots(1, figsize=(20, 16))
sns.heatmap(corr, ax=ax3, cmap='RdBu_r', center=0,
            xticklabels=False, yticklabels=False, cbar=False)
for c in partiColors.values():
    ax3.scatter([-1000], [-1000], color=c)
parties = other_data['parti']
for i, party in enumerate(parties):
    ax3.add_patch(plt.Rectangle((-0.5, i), corr.shape[0], 1, 
                       fill=True, color=partiColors[party], alpha=1))
    ax3.add_patch(plt.Rectangle((i, -0.5), 1, corr.shape[0], 
                       fill=True, color=partiColors[party], alpha=1))
ax3.legend(partiColors.keys(),
                bbox_to_anchor=(1.05, 1), 
                loc='upper left',
                title='Party')
ax3.set_title('Correlation Matrix with Party Colors')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix with Party Colors')

# %%
# Out:
# k-means: 0.183
